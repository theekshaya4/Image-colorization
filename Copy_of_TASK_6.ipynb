# %% [markdown]
# <a href="https://colab.research.google.com/github/theekshaya4/Image-colorization/blob/main/Copy_of_TASK_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open video stream or file.")
    exit()

while True:
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to read frame from camera. Exiting.")
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    colored = cv2.applyColorMap(gray, cv2.COLORMAP_JET)

    cv2.imshow("Colorized", colored)

    if cv2.waitKey(1)==27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Error: Could not open video stream or file.
# Error: Failed to read frame from camera. Exiting.
